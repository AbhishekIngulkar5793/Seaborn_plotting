# %% [markdown]
# ## Categorical plotting
# - When one or both variables under study are categorical, then use plots like, stripplot(), swarmplot(), etc.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Categorical Scatter plots
#stripplot()
#stripplot():  -is used when one of the variable under study is categorical. 
# -It represents the data in sorted order along any one of the axis.

# %%
#load penguin dataset
p = sns.load_dataset('penguins')
p[:2]
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female

# %%
#check unique island
p.island.unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
#lets plot bodymass w.r.t island using stripplot
sns.stripplot(x='island',y='body_mass_g',data=p)
# Out:
# <AxesSubplot:xlabel='island', ylabel='body_mass_g'>

# %% [raw]
# As pr above plot,
# We have more number of entries from Biscoe Island also body mass from this island
# is higher than remaining 2
# Torgersen and Dream island penguins almost have same body mass range

# %% [markdown]
# ## stripplot()

# %%
#Draw a scatterplot where one variable is categorical.
# On the basis of Species differentiate with respect to body massbb
sns.stripplot(x='species',y='body_mass_g',data=p)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
p.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
#p.species.value_counts().plot.bar() OR,
p.species.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(p.species)
# Out:
# C:\Users\abhis\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
# in above plot i want to see genderwise distribution
sns.stripplot(x='species',y='body_mass_g',data=p,hue='sex')
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
# hue=species
sns.stripplot(x='species',y='body_mass_g',data=p,hue='species')
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
#load tips dataset as tt
#check some categorical columns
# check scatter plot with genderwise tip
#genderwise total_bill
#time vs total_bill hue='sex'
tt = sns.load_dataset('tips')
tt[:2]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
#check some categorical columns
# check dtypes
tt.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# we have: sex, smoker, day, and time as categorical data columns
# and total_bill, tip, and size as the continuous(float)/discreet(int) data columns

# %%
#check scatter plot with genderwise tip
sns.scatterplot(x='sex', y='tip', data=tt)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
#genderwise total_bill
sns.scatterplot(x='sex', y='total_bill', data=tt)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
#time vs total_bill hue='sex'
sns.scatterplot(x='time', y='total_bill', data=tt, hue='sex')
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %% [markdown]
# ### Distribution plots

# %% [markdown]
# Performing comparison with the categories

# %% [markdown]
# # Box plot

# %% [markdown]
# Boxplot is the convenient way to visualize the distribution of data through their quartiles

# %%
# check unique days
tt.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
# set title as 'box plot for Day vs total_bill'
sns.boxplot(x='day', y='total_bill', data=tt, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Bar plot

# %% [markdown]
# - The barplot() shows the relation between a categorical variable and a continuous variable.
# - The data is represented in rectangular bars where the length the bar represents the proportion of the data in that category.

# %%
# penguins dataset
p[:2]
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female

# %%
# species vs bill_length_mm
sns.barplot(x='species',y='bill_length_mm',data=p)
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %%
#hue=island
sns.barplot(x='species',y='bill_length_mm',data=p,hue='island')
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %%
sns.countplot(x='species',data=p,hue='island')
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
p[:2]
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female

# %%
sns.boxplot(x='species',y='bill_length_mm',data=p)
#sns.boxplot(x='species',y='bill_depth_mm',data=p)
# Out:
# <AxesSubplot:xlabel='species', ylabel='bill_length_mm'>

# %%
p.query("species=='Gentoo' & bill_length_mm > 57") #outlier
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 253  Gentoo  Biscoe            59.6           17.0              230.0
#
#      body_mass_g   sex
# 253       6050.0  Male

# %%
# embarked vs survived

# %% [markdown]
# # Count plot
# - A special case in barplot is to show the no of observations in each category rather than
# - computing a statistic for a second variable. For this, we use countplot()

# %%
#use titanic dataset
t = sns.load_dataset('titanic')
t[:2]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
#hue=sex
sns.countplot(x='class',data=t,hue='sex')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
# classwise survival rate
sns.countplot(x='survived',data=t,hue='class')
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
# genderwise survival rate
sns.countplot(x='survived',data=t,hue='sex')
plt.xticks([0,1],['Dead','Alive'])
plt.show()

# %%
t.groupby(['survived','sex']).pclass.count()
# Out:
# survived  sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: pclass, dtype: int64

# %%
t[:2]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

# %%
sns.countplot(x='class',data=t,hue='survived')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
t.sex.value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %% [markdown]
# By observing the above result,we can conclude, more male passengers present than female. More specifically, in third class category we have more male candidates Female are less in count but their survival rate is too high.

# %% [markdown]
# ## Violine plot: KDE + Box

# %%
#Violine plot: KDE + Box 
sns.violinplot(x = 'fare',data=t)
# Out:
# <AxesSubplot:xlabel='fare'>

# %%
# sex vs age
sns.violinplot(x='sex',y='age',data=t)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
sns.violinplot(x='class',y='age',data=t,hue='survived')
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %% [markdown]
# ## heatmap

# %%
# when we want to show matrix representation with respect to weight of the each feature
# then go with heatmap

# %%
#correlation: It is known as pearson correlation
t.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
#check corr of few columns

# %%
#heatmap
plt.figure(figsize=(18,12))
out = t.corr()
sns.heatmap(out,annot=True,cmap='gist_rainbow')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Feature Selection methods:

# %% [markdown]
# - loc means, label based selection
# - iloc means, index based selection

# %%
t[:2]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
